# %%
#importing the libraries to use
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sb 
from collections import Counter
import scipy.stats as stats

# %%
#reading the original dataset 
dfo = pd.read_csv('Life Expectancy Data.csv')
pd.set_option("display.max_columns",None)
old_colnames=dfo.columns
new_colnames=['Country','Year','Status','Life_expectancy','Adult Mortality','infant deaths','Alcohol','percentage expenditure','Hepatitis B','Measles','BMI','under-five deaths','Polio','Total expenditure','Diphtheria','HIV/AIDS','GDP','Population','thinness 1-19 years','thinness 5-9 years','Income composition of resources','Schooling']
dfo=dfo.rename(columns=dict(zip(old_colnames,new_colnames)))
dfo
# Out:
#           Country  Year      Status  Life_expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
#reading all the columns of the dataset
dfo.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness 1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
#describing the original dataset 
dfo.describe()
# Out:
#               Year  Life_expectancy  Adult Mortality  infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
dfo.shape
# Out:
# (2938, 22)

# %%
dfo.head(20)
# Out:
#         Country  Year      Status  Life_expectancy  Adult Mortality  \
# 0   Afghanistan  2015  Developing             65.0            263.0
# 1   Afghanistan  2014  Developing             59.9            271.0
# 2   Afghanistan  2013  Developing             59.9            268.0
# 3   Afghanistan  2012  Developing             59.5            272.0
# 4   Afghanistan  2011  Developing             59.2            275.0
# 5   Afghanistan  2010  Developing             58.8            279.0
# 6   Afghanistan  2009  Developing             58.6            281.0
# 7   Afghanistan  2008  Developing             58.1            287.0
# 8   Afghanistan  2007  Developing             57.5            295.0
# 9   Afghanistan  2006  Developing             57.3            295.0
# 10  Afghanistan  2005  Developing             57.3            291.0
# 11  Afghanistan  2004  Developing             57.0            293.0
# 12  Afghanistan  2003  Developing             56.7            295.0
# ...

# %%
# describing the dataset dropping rows without including missing value
dfo.dropna().describe()
# Out:
#               Year  Life_expectancy  Adult Mortality  infant deaths  \
# count  1649.000000      1649.000000      1649.000000    1649.000000
# mean   2007.840509        69.302304       168.215282      32.553062
# std       4.087711         8.796834       125.310417     120.847190
# min    2000.000000        44.000000         1.000000       0.000000
# 25%    2005.000000        64.400000        77.000000       1.000000
# 50%    2008.000000        71.700000       148.000000       3.000000
# 75%    2011.000000        75.000000       227.000000      22.000000
# max    2015.000000        89.000000       723.000000    1600.000000
#
#            Alcohol  percentage expenditure  Hepatitis B        Measles  \
# count  1649.000000             1649.000000  1649.000000    1649.000000
# mean      4.533196              698.973558    79.217708    2224.494239
# std       4.029189             1759.229336    25.604664   10085.802019
# ...

# %%
#checking for null cells in the original dataset
dfo.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life_expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness 1-19 years                 34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
dfo.index
# Out:
# RangeIndex(start=0, stop=2938, step=1)

# %%
# Printing all dataset with interval 12
dfo[0:2938:12]
# Out:
#           Country  Year      Status  Life_expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 12    Afghanistan  2003  Developing             56.7            295.0
# 24        Albania  2007  Developing             75.9              9.0
# 36        Algeria  2011  Developing             74.9            116.0
# 48         Angola  2015  Developing             52.4            335.0
# ...           ...   ...         ...              ...              ...
# 2880     Viet Nam  2009  Developing             75.0            134.0
# 2892        Yemen  2013  Developing             65.4            226.0
# 2904        Yemen  2001  Developing             61.1            251.0
# 2916       Zambia  2005  Developing             49.3            554.0
# 2928     Zimbabwe  2009  Developing             50.0            587.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
# finding whether or not there is an empty colunm
dfo.isnull().all()
# Out:
# Country                            False
# Year                               False
# Status                             False
# Life_expectancy                    False
# Adult Mortality                    False
# infant deaths                      False
# Alcohol                            False
# percentage expenditure             False
# Hepatitis B                        False
# Measles                            False
# BMI                                False
# under-five deaths                  False
# Polio                              False
# Total expenditure                  False
# Diphtheria                         False
# HIV/AIDS                           False
# GDP                                False
# Population                         False
# thinness 1-19 years                False
# thinness 5-9 years                 False
# Income composition of resources    False
# Schooling                          False
# dtype: bool

# %%
# Count if there is any column with at least one empty entry
dfo.isnull().any().value_counts()
# Out:
# True     14
# False     8
# dtype: int64

# %%
# Excluding Country, Year, and Status
numb=dfo.drop(['Country','Year','Status'],axis=1)
numb
# Out:
#       Life_expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0                65.0            263.0             62     0.01
# 1                59.9            271.0             64     0.01
# 2                59.9            268.0             66     0.01
# 3                59.5            272.0             69     0.01
# 4                59.2            275.0             71     0.01
# ...               ...              ...            ...      ...
# 2933             44.3            723.0             27     4.36
# 2934             44.5            715.0             26     4.06
# 2935             44.8             73.0             25     4.43
# 2936             45.3            686.0             25     1.72
# 2937             46.0            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles   BMI  under-five deaths  \
# 0                  71.279624         65.0     1154  19.1                 83
# ...

# %%
# mean for life expectancy
dfo['Life_expectancy'].mean()
# Out:
# 69.22493169398912

# %%
# print Countries above mean
pd.set_option("display.max_rows",None)

dfo[dfo['Life_expectancy'] > dfo['Life_expectancy'].mean()][['Country', 'Life_expectancy']]
# Out:
#                                                 Country  Life_expectancy
# 16                                              Albania             77.8
# 17                                              Albania             77.5
# 18                                              Albania             77.2
# 19                                              Albania             76.9
# 20                                              Albania             76.6
# 21                                              Albania             76.2
# 22                                              Albania             76.1
# 23                                              Albania             75.3
# 24                                              Albania             75.9
# 25                                              Albania             74.2
# 26                                              Albania             73.5
# 27                                              Albania             73.0
# ...

# %% [markdown]
# ### There  are empty cells in the given dataset so we drop the empty cells

# %%
#Dropping null cells in the dataset to generate new dataset from the original one
pd.set_option("display.max_rows",None)
dfn = dfo.dropna()
dfn
# Out:
#                        Country  Year      Status  Life_expectancy  \
# 0                  Afghanistan  2015  Developing             65.0
# 1                  Afghanistan  2014  Developing             59.9
# 2                  Afghanistan  2013  Developing             59.9
# 3                  Afghanistan  2012  Developing             59.5
# 4                  Afghanistan  2011  Developing             59.2
# 5                  Afghanistan  2010  Developing             58.8
# 6                  Afghanistan  2009  Developing             58.6
# 7                  Afghanistan  2008  Developing             58.1
# 8                  Afghanistan  2007  Developing             57.5
# 9                  Afghanistan  2006  Developing             57.3
# 10                 Afghanistan  2005  Developing             57.3
# 11                 Afghanistan  2004  Developing             57.0
# 12                 Afghanistan  2003  Developing             56.7
# ...

# %%
#printing the last five rows of the new dataset
dfn.tail()
# Out:
#        Country  Year      Status  Life_expectancy  Adult Mortality  \
# 2933  Zimbabwe  2004  Developing             44.3            723.0
# 2934  Zimbabwe  2003  Developing             44.5            715.0
# 2935  Zimbabwe  2002  Developing             44.8             73.0
# 2936  Zimbabwe  2001  Developing             45.3            686.0
# 2937  Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 2933             27     4.36                     0.0         68.0       31
# 2934             26     4.06                     0.0          7.0      998
# 2935             25     4.43                     0.0         73.0      304
# 2936             25     1.72                     0.0         76.0      529
# 2937             24     1.68                     0.0         79.0     1483
#
#        BMI  under-five deaths  Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# ...

# %%
#descriptive statistics of the new dataset
dfn.describe()
# Out:
#               Year  Life_expectancy  Adult Mortality  infant deaths  \
# count  1649.000000      1649.000000      1649.000000    1649.000000
# mean   2007.840509        69.302304       168.215282      32.553062
# std       4.087711         8.796834       125.310417     120.847190
# min    2000.000000        44.000000         1.000000       0.000000
# 25%    2005.000000        64.400000        77.000000       1.000000
# 50%    2008.000000        71.700000       148.000000       3.000000
# 75%    2011.000000        75.000000       227.000000      22.000000
# max    2015.000000        89.000000       723.000000    1600.000000
#
#            Alcohol  percentage expenditure  Hepatitis B        Measles  \
# count  1649.000000             1649.000000  1649.000000    1649.000000
# mean      4.533196              698.973558    79.217708    2224.494239
# std       4.029189             1759.229336    25.604664   10085.802019
# ...

# %%
dfo[['Adult Mortality', 'infant deaths', 'Population','GDP', 'Total expenditure', 'Hepatitis B', 'Alcohol']].max()
# Out:
# Adult Mortality      7.230000e+02
# infant deaths        1.800000e+03
# Population           1.293859e+09
# GDP                  1.191727e+05
# Total expenditure    1.760000e+01
# Hepatitis B          9.900000e+01
# Alcohol              1.787000e+01
# dtype: float64
